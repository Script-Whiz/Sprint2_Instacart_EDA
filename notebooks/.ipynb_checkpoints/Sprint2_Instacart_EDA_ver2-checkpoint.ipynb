# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment</b>
#
# Hi, Deborah! I am a reviewer on this project. Glad to see you here!
#
#
# Before we start, I want to pay your attention to the color marking:
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ✔️</b>
#
# Great solutions and ideas that can and should be used in the future are in green comments.
# </div>
#
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ⚠️</b>
#
# Yellow color indicates what should be optimized. This is not necessary, but it will be great if you make changes to this project.
# </div>
#
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# Issues that need to be corrected to get right results are indicated in red comments. Note that the project cannot be accepted until these issues are resolved.
# </div>
#
# <hr>
#
# **Please, use some color other than those listed to highlight answers to my comments.**
# I would also ask you **not to change, move or delete my comments** so that it would be easier for me to navigate during the next review.
#
# In addition, my comments are defined as headings.
# They can mess up the content; however, they are convenient, since you can immediately go to them. I will remove the headings from my comments in the next review.
#
#
#
# <hr>
#
# <font color='dodgerblue'>**A few words about the project:**</font> you did a good job, everything is clear and neat. The project is easy to read, which is definitely a plus. There are a lot graphs. It is good, visualization never hurts. I still have some questions that I've written in my comments. I've also left there some recommendations for improving the project.
#
#
# I will wait for the project for a second review :)
#
#
#
# 📌 Here are some hints that may help you with Markdown cells:
# <hr style="border-top: 3px solid purple; "></hr>
#
# You can leave comments using this code inside a Markdown cell:
#
#
#     <div class="alert alert-info">
#     <h2> Student's comment</h2>
#
#     Your text here.
#     </div>
#
#
#
#     <font color='red'> This code is used to change text color. </font>
#
# <font color='red'> It will look like this. </font>
#
# If you don't want your comments to be headings, replace **h2** with **b** or just add `<a class="tocSkip">` after the phrase *Student's comment*.
#
#
# You can find out how to **format text** in a Markdown cell or how to **add links** [here](https://sqlbak.com/blog/jupyter-notebook-markdown-cheatsheet) и [and here](https://medium.com/analytics-vidhya/the-ultimate-markdown-guide-for-jupyter-notebook-d5e5abf728fd).
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 2</b>
#
#
# Thank you for sending a new version of the project 😊 I've left a few comments titled as **Reviewer's comment 2**. Please take a look :)
#
#
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 3</b>
#
#
# Thank you very much for your diligence! I've left a couple of new comments with digit 3.  However, there are no issues that need to be fixed.
#
#
#
#
# Your project has passed code review. Congratulations 😊
#
#
#
# This is a good [article](https://www.kaggle.com/ramprakasism/pandas-75-exercises-with-solutions/notebook) with 75 pandas exercises and solutions. You can go along the exercises and compare your solution with the solution in the article.
#
#
#
# Good luck! 😊
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment ❌</b>
#
# First things first. The introduction is the initial paragraph that each project, each essay or any article should have. It is important to write an introductory part, because it gives an idea about the content of the project.
#
#
# Please add a title and project description.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <h1>  Instacart Ordering Habits of Customers</h1>
# <h2>I will be exploring 5 different Instacart datasets to gather information about buying habits of customers. I will answer these questions:<a class="tocSkip"></h2>
#
# - How many customers place orders for each hour of the day?
# - What day of the week do people shop for groceries?
# - How long will people wait until placing their next order?  <br>
# <br>
# - Is there a difference in 'order_hour_of_day' distributions on Wednesdays and Saturdays?
# - What is the distribution for the number of orders that customers place?
# - What are the top 20 products that are ordered most frequently?  <br>
# <br>
# <br>
# - What are the top 20 items that are reordered most frequently?
# - For each product, what proportion of its orders are reorders?
# - What are the top 20 items that people put in their carts first?
#
# </div></font color>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Great! :) It's a good habit actually. I have about 200 notebooks on my laptop with different tasks. Without a good intro it would be hard to remember what a particular notebook is about.
#
#
#
# Nice colors, by the way :)
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import HTML, display

# %% [markdown]
# # <span style="color:red">Open the data files:</span>

# %%
#Read in the Instacart Orders dataframe. Using sep parameter because the columns are separated by semi-colons (;)
orders = pd.read_csv('/datasets/instacart_orders.csv', sep=";")
#orders.info
display(orders.head(25))
# Out:
#     order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0    1515936   183418            11          6                 13
# 1    1690866   163593             5          5                 12
# 2    1454967    39980             4          5                 19
# 3    1768857    82516            56          0                 20
# 4    3007858   196724             2          4                 12
# 5    1843871    20084             5          0                 11
# 6    2511640   148233            40          3                  8
# 7    2521283    97711             2          0                 18
# 8    2266494    34954            40          5                 15
# 9     446014    15356             2          4                  8
# 10   1162566    43738            33          4                 11
# 11    102585   191558            18          6                 16
# 12   2276302   190167            21          1                 12
# ...

# %%
orders.shape
# Out:
# (478967, 6)

# %%
orders.describe()
# Out:
#            order_id        user_id   order_number      order_dow  \
# count  4.789670e+05  478967.000000  478967.000000  478967.000000
# mean   1.709947e+06  102966.537475      17.157808       2.775058
# std    9.869480e+05   59525.328991      17.704688       2.045869
# min    4.000000e+00       2.000000       1.000000       0.000000
# 25%    8.564685e+05   51414.000000       5.000000       1.000000
# 50%    1.709522e+06  102633.000000      11.000000       3.000000
# 75%    2.562990e+06  154419.000000      23.000000       5.000000
# max    3.421079e+06  206209.000000     100.000000       6.000000
#
#        order_hour_of_day  days_since_prior_order
# count      478967.000000           450148.000000
# mean           13.446676               11.101751
# std             4.224986                9.189975
# min             0.000000                0.000000
# 25%            10.000000                4.000000
# 50%            13.000000                7.000000
# ...

# %%
orders.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %%
#missing_values_count = orders['days_since_prior_order'].isna().sum()
#print(f"Number of missing values in 'days_since_prior_order': {missing_values_count}")

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>The orders dataset was read in, with the sep parameter equal to ';' because the data was not separated by commas. There are 6 columns.  The column days_since_prior_order  datatype needs to change to int64.</b>
# </div></font>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
# It's great that you add intermediate conclusions, since they are quite important.
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>  Reviewer's comment ⚠️</b>
#
# However, try not to use the `#` with the regular text, since the conclusion looks more like a title.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Looks good!
# </div>

# %%
# Read in the Products dataframe. 
products = pd.read_csv('/datasets/products.csv', sep=";")
products.info
#display(products)
# Out:
# <bound method DataFrame.info of        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49689       49690                      HIGH PERFORMANCE ENERGY DRINK
# 49690       49691                      ORIGINAL PANCAKE & WAFFLE MIX
# 49691       49692    ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR
# 49692       49693                             SPRING WATER BODY WASH
# 49693       49694                            BURRITO- STEAK & CHEESE
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# ...

# %%
products.shape
# Out:
# (49694, 4)

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>The product dataset was read in, with the sep parameter equal to ';' because the data was not separated by commas.  There are 4 columns. The datatypes look correct.</b>
# </div></font>

# %%
#Read in the Aisles dataframe.
aisles = pd.read_csv('/datasets/aisles.csv', sep=";")
aisles.shape
# Out:
# (134, 2)

# %%
#aisles.info
display(aisles.head(100))
# Out:
#     aisle_id                       aisle
# 0          1       prepared soups salads
# 1          2           specialty cheeses
# 2          3         energy granola bars
# 3          4               instant foods
# 4          5  marinades meat preparation
# ..       ...                         ...
# 95        96                  lunch meat
# 96        97       baking supplies decor
# 97        98               juice nectars
# 98        99     canned fruit applesauce
# 99       100                     missing
#
# [100 rows x 2 columns]

# %%
aisles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>The aisles dataset was read in, with the sep parameter equal to ';' because the data was not separated by commas.  There are 2 columns. The datatypes look correct.</b>
# </div></font>

# %%
#Read in the Departments dataframe.
depts = pd.read_csv('/datasets/departments.csv', sep=";")
depts.shape
# Out:
# (21, 2)

# %%
display(depts)
# Out:
#     department_id       department
# 0               1           frozen
# 1               2            other
# 2               3           bakery
# 3               4          produce
# 4               5          alcohol
# 5               6    international
# 6               7        beverages
# 7               8             pets
# 8               9  dry goods pasta
# 9              10             bulk
# 10             11    personal care
# 11             12     meat seafood
# 12             13           pantry
# 13             14        breakfast
# 14             15     canned goods
# 15             16       dairy eggs
# 16             17        household
# 17             18           babies
# 18             19           snacks
# 19             20             deli
# 20             21          missing

# %%
depts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes

# %%
#print(depts[depts['department_id'] == 21])

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>The departments dataset was read in, with the sep parameter equal to ';' because the data was not separated by commas. There are 2 columns. The datatypes look correct.</b>
# </div></font>

# %% [markdown]
# ### Products Order dataset

# %%
# Read in the Products Order dataset.
# This dataset shows the order that the items were placed in to the cart.
item_order = pd.read_csv('/datasets/order_products.csv', sep=";")
item_order.shape
# Out:
# (4545007, 4)

# %%
display(item_order)
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 0         2141543       11440               17.0          0
# 1          567889        1560                1.0          1
# 2         2261212       26683                1.0          1
# 3          491251        8670               35.0          1
# 4         2571142        1940                5.0          1
# ...           ...         ...                ...        ...
# 4545002    577211       15290               12.0          1
# 4545003   1219554       21914                9.0          0
# 4545004    692640       47766                4.0          1
# 4545005    319435         691                8.0          1
# 4545006   1398151       28733                9.0          0
#
# [4545007 rows x 4 columns]

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# added parenthesis on info
# </div></font>

# %%
item_order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  float64
#  3   reordered          int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>  Reviewer's comment ⚠️</h2>
#
# If you want to use the *method* `info`, then try to add parantheses.
#
# </div>

# %%
item_order.dtypes
# Out:
# order_id               int64
# product_id             int64
# add_to_cart_order    float64
# reordered              int64
# dtype: object

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>The products order dataframe was read in, using the sep parameter, because the columns are separated by semi colons (;)  Why is add_to_cart_order a float datatype? That should be changed to int.</b>
# </div></font>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment ✔️</h2>
#
# Nice introductory part!
#
# </div>

# %% [markdown]
# # <span style="color:red">Preprocess the data:</span>

# %% [markdown]
# ## Find and remove duplicate values (and describe why you make your choices)

# %% [markdown]
# ### `orders` data frame

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>
# Commented out this unecessary step (below) of creating 'num_duplicates'</b>
# </div></font>

# %%
# Check for duplicated orders, and count how many duplicates there are. 
orders_duplicates = orders.duplicated()

#num_duplicates = orders_duplicates.sum()

print("Number of duplicate rows in the orders dataframe:")
print(orders_duplicates.sum())
# Out:
# Number of duplicate rows in the orders dataframe:
# 15

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
#
# It's very important to check for the duplicates because sometimes they can impair the quality of the analysis.
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>  Reviewer's comment ⚠️</h2>
#
#
#
# However, you do not need to create a variable for it.
# </div>

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>I commented out dropna, (below), and will not drop orders with missing values right now. I will also need to change the datatype of 'days_since_prior_order' later in the code, and not now. The reason is because in order to change the datatype, I will need to use fillna with '0', and this would mark all of these 'days_since_prior_order' as not missing. </b>
# </div></font>

# %%
#Fill Nan with a placeholder of '0'
#orders['days_since_prior_order'] = orders['days_since_prior_order'].fillna(0)
#orders = orders.dropna(subset=['days_since_prior_order'])

#Need to change datatype later on in the code.
#Change datatype of days_since_prior_order from float to int64. 
#orders['days_since_prior_order'] = orders['days_since_prior_order'].astype('int64')

#Verify that days_since_prior_order is now int64 datatype
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Since one of the tasks will be related to these Nan-s, do not drop them. Moreover, why do we need to delete them? We lose rows that contain a lot of important information. The fact that there're Nan-s in the `days_since_prior_order`  column may imply that these people had only one order. In this case, Nan-s have some meaning.
#
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Good!
# </div>

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>Changed print to display, to make printout easier to read.</b>
# </div></font>

# %%
# Check for all orders placed Wednesday at 2:00 AM (assuming that Weds. is the 4th day of the week.)
orders_result = orders.query('order_dow == 3 and order_hour_of_day == 2')
#display(orders_result)
display(orders_result.value_counts())
# Out:
# order_id  user_id  order_number  order_dow  order_hour_of_day  days_since_prior_order
# 794638    50898    24            3          2                  2.0                       2
# 1919531   191501   32            3          2                  7.0                       2
# 2845099   31189    11            3          2                  7.0                       2
# 467134    63189    21            3          2                  2.0                       2
# 1112182   202304   84            3          2                  6.0                       2
#                                                                                         ..
# 898850    14380    4             3          2                  30.0                      1
# 851025    168387   54            3          2                  15.0                      1
# 819551    29545    15            3          2                  4.0                       1
# ...

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>  Reviewer's comment ⚠️</h2>
#
#
# Try to use **display** instead of **print** for the dataframes :)
#
#
# Display is a great thing. However, jupyter notebook is an interactive environment that already includes display. When we call a dataframe (see the code below), jupyter prints this dataframe like we do with the display method:
#
# </div>

# %%
# Reviewer's code

display(orders_result.head(3))

orders_result.tail(3)
# Out:
#        order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838    2766110   162084            41          3                  2
# 5156    2190225   138285            18          3                  2
# 15506    553049    58599            13          3                  2
#
#        days_since_prior_order
# 4838                     16.0
# 5156                     11.0
# 15506                     7.0
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#         days_since_prior_order
# 459635                    21.0
# 468324                     3.0
# 477526                     3.0

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>There are 101 orders that were placed on Weds. at 2am.</b>
# </div></font>

# %%
# Remove duplicate orders. 
print("Number of rows before removing duplicates from orders:")
print(len(orders))
print

orders = orders.drop_duplicates()

# Reset the index and drop the old index
orders = orders.reset_index(drop=True)

print("Number of rows after removing duplicates:")
print(len(orders))
# Out:
# Number of rows before removing duplicates from orders:
# 478967
# Number of rows after removing duplicates:
# 478952

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>I have added a line of code to reset the index.  displaying the head or tail showed the same output, so I removed my display code.  With so many rows, I don't know where, in the dataframe, is a good example of showing that the index was reset.</b>
# </div></font>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>  Reviewer's comment ⚠️</b>
#
#
#
# It is better to reset indices and drop the old ones.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Correct.
# </div>

# %%
# Double check for duplicate rows
print("Number of duplicate rows in orders dataframe:")
print(orders.duplicated().sum())
# Out:
# Number of duplicate rows in orders dataframe:
# 0

# %%
# Double check for duplicate order IDs only
duplicate_order_ids = orders.duplicated(subset='order_id').sum()
print(f"Number of duplicate order IDs: {duplicate_order_ids}")
# Out:
# Number of duplicate order IDs: 0

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>Cleaned up the orders dataframe:</b>
# <br><br>
# - I checked to see if there were duplicate rows in the orders dataframe, and I got a count of how many.
# <br>
# - I changed all Nan to '0', with fillna, so that I could change the datatype without error.
# <br>
# - I changed the data type of the days_since_prior_order column because it made no sense that it was a float.
# <br>
# - I checked to see how many orders were placed at 2am (between the hours of 2am-3am).
# <br>
# - I removed the duplicate rows, for the orders dataframe, and double checked that they were indeed removed.
# <br>
# <br>
# - I reset the index on the orders dataframe.
# <br>
# <br>
# - I double checked that duplicates were removed from the order_ID column, using the subset parameter on the duplicated() method.
# </div></font color>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
#
# Correct.</div>

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <h3>Cleaning the `products` data frame: </h3>
# </div></font color>

# %%
display(products)
products.value_counts()
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49689       49690                      HIGH PERFORMANCE ENERGY DRINK
# 49690       49691                      ORIGINAL PANCAKE & WAFFLE MIX
# 49691       49692    ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR
# 49692       49693                             SPRING WATER BODY WASH
# 49693       49694                            BURRITO- STEAK & CHEESE
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 2            94              7
# ...

# %%
# Check for fully duplicate rows in the products dataframe.
dupe_prod_rows = products.duplicated()
dupe_prod_count = dupe_prod_rows.sum()
print(f"Number of fully duplicate rows in products dataframe: {dupe_prod_count}")
# Out:
# Number of fully duplicate rows in products dataframe: 0

# %%
# Check for just duplicate product IDs
dup_prod_ids = products.duplicated(subset='product_id').sum()
print(f"Number of duplicate product IDs in products dataframe: {dup_prod_ids}")
print(dup_prod_ids)
# Out:
# Number of duplicate product IDs in products dataframe: 0
# 0

# %%
# Check for just duplicate product names (convert names to lowercase to compare better)
products['product_name'] = products['product_name'].str.lower()

#print(products['product_name'])
print()
#Finds duplicate product names, and create a boolean result
dupe_prod_names = products.duplicated(subset='product_name').sum()
print(f"Number of duplicated product names: {dupe_prod_names}")

print()
unique_prod_names = products['product_name'].nunique()
print(f"Number of unique product names: {unique_prod_names}")
# Out:
# Number of duplicated product names: 1361
#
# Number of unique product names: 48332

# %%
# Check for duplicate product names that aren't missing
# Filter rows with Nan. The ~ reverses the outcome.
not_nan_prod = products[~products['product_name'].isna()]

#print(non_null_products)
# Now look for duplicates
dupe_prod_names = not_nan_prod.duplicated(subset='product_name').sum()
print(f"Number of duplicated product names: {dupe_prod_names}")
# Out:
# Number of duplicated product names: 104

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>I made no changes in this "Cleaning the Products Dataframe" section above.</b>
# </div></font color>

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>There were no duplicate rows in the products dataframe. There were also no duplicates of the product_id. I converted the product_name column to lowercase, then I checked to see if there were duplicates. There are 1361 duplicate product names. Then I checked to see if there were any Nan (missing data) in the product_name column. Then, I took the list of non-null product names, and used duplicated to find out if there were any duplicate product names. </b>
# </div></font color>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>Reviewer's comment ✔️</h2>
#
#
# They have different `product_id`, so I am not sure whether we should treat them as duplicates. It's a good habit to always analyze the result :)
#
#
# </div>

# %% [markdown]
# ### `departments` data frame

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>I added a printout for len of depts, to verify that it really was a small dataframe. I also added "Value Counts" above the value_counts printout, to make it clearer as to what you're looking at.</b>
# </div></font color>

# %%
print(len(depts))
display(depts)

print()
display("Value Counts of depts dataframe:")
depts.value_counts()
# Out:
# 21
#     department_id       department
# 0               1           frozen
# 1               2            other
# 2               3           bakery
# 3               4          produce
# 4               5          alcohol
# 5               6    international
# 6               7        beverages
# 7               8             pets
# 8               9  dry goods pasta
# 9              10             bulk
# 10             11    personal care
# 11             12     meat seafood
# 12             13           pantry
# 13             14        breakfast
# 14             15     canned goods
# 15             16       dairy eggs
# 16             17        household
# 17             18           babies
# 18             19           snacks
# 19             20             deli
# 20             21          missing
# 'Value Counts of depts dataframe:'
# department_id  department
# 1              frozen             1
# 12             meat seafood       1
# 20             deli               1
# ...

# %%
#Convert the values in the department column to lowercase.
depts['department'] = depts['department'].str.lower()

# %%
#Finds duplicate department names, and create a boolean result
dupe_dept_names = depts.duplicated(subset='department').sum()
print(f"Number of duplicated department names: {dupe_dept_names}")
# Out:
# Number of duplicated department names: 0

# %%
depts_duplicates = depts.duplicated()
num_dept_duplicates = depts_duplicates.sum()
print("Number of duplicate rows in the depts dataframe:")
print(num_dept_duplicates)
# Out:
# Number of duplicate rows in the depts dataframe:
# 0

# %%
<div class="alert alert-info"><font color='hotpink'>
<b>Depts cleanup:</b>
<br>
- I converted the departments column to lowercase, just in case there were any uppercase. 
<br>
- I used duplicated to check to see how many duplicate department names there were. There were none.
<br>
- I checked to see how many duplicate rows there were in the depts dataframe, using the duplicated() method. There were no duplicates.
</div></font color>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Very good.
# </div>

# %% [markdown]
# ### `aisles` data frame

# %%
display(aisles)

print()
print("Value_counts:")
aisles.value_counts()
# Out:
#      aisle_id                       aisle
# 0           1       prepared soups salads
# 1           2           specialty cheeses
# 2           3         energy granola bars
# 3           4               instant foods
# 4           5  marinades meat preparation
# ..        ...                         ...
# 129       130    hot cereal pancake mixes
# 130       131                   dry pasta
# 131       132                      beauty
# 132       133  muscles joints pain relief
# 133       134  specialty wines champagnes
#
# [134 rows x 2 columns]
# Value_counts:
# aisle_id  aisle
# 1         prepared soups salads         1
# 85        food storage                  1
# 99        canned fruit applesauce       1
# 98        juice nectars                 1
# 97        baking supplies decor         1
#                                        ..
# 40        dog food care                 1
# 39        seafood counter               1
# 38        frozen meals                  1
# ...

# %%
#Convert the values, in the aisle column, to lowercase.
aisles['aisle'] = aisles['aisle'].str.lower()

# %%
#Finds duplicate aisle names, and create a boolean result
dupe_aisle_names = aisles.duplicated(subset='aisle').sum()
print(f"Number of duplicated department names: {dupe_aisle_names}")
# Out:
# Number of duplicated department names: 0

# %%
# Check for duplicated rows in aisles dataframe, and count how many duplicates there are. 
aisles_duplicates = aisles.duplicated()
num_aisles_duplicates = aisles_duplicates.sum()
print("Number of duplicate rows in the aisles dataframe:")
print(num_aisles_duplicates)
# Out:
# Number of duplicate rows in the aisles dataframe:
# 0

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>
# <br>
# - Answered your question of whether or not there were duplicates in the aisle_id column.
# <br>
# - added this import, to first cell, up above, to accomodate colored font inside a code cell... "from IPython.display import HTML, display"</b>
# </div></font color>

# %%
dupe_aisle_id = aisles.duplicated(subset='aisle_id').sum()
display(HTML(f"<div style='color: hotpink;'><b>There are {dupe_aisle_id} duplicates in the aisle_id column.</b></div>"))
# Out:
# <div style='color: hotpink;'><b>There are 0 duplicates in the aisle_id column.</b></div>

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>Aisles cleanup:</b>
# <br>
# - I converted the aisle column to lowercase just in case there were uppercase. Then I checked for duplicate aisle names. There were no duplicate aisle names.
# - I checked for duplicate rows in the aisles dataframe. There were no duplicates.
# </div></font color>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Are there any duplicates in `aisle_id`?
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Great! :)
#
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
item_order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  float64
#  3   reordered          int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %%
# Check for fully duplicate rows
dupe_item_order = item_order.duplicated()
item_order_num_duplicates = dupe_item_order.sum()
print(f"Number of duplicate rows in the 'item_order' dataframe: {item_order_num_duplicates}")
# Out:
# Number of duplicate rows in the 'item_order' dataframe: 0

# %%
# Double check for any other tricky duplicates
print(item_order.head(5))
print()
print(f"Number of rows in item_order dataset: {len(item_order)}")
#print(len(item_order))
print()

dupe_item_order = item_order.duplicated(subset='order_id').sum()
#Marks all occurances of duplicates as True
#dupe_item_order = item_order['order_id'].duplicated(keep=False)
print(f"Number of duplicate order_id: {dupe_item_order}")
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0   2141543       11440               17.0          0
# 1    567889        1560                1.0          1
# 2   2261212       26683                1.0          1
# 3    491251        8670               35.0          1
# 4   2571142        1940                5.0          1
#
# Number of rows in item_order dataset: 4545007
#
# Number of duplicate order_id: 4094961

# %% [markdown]
# <h3> Created a function for the HTML outputting.</h3>

# %%
def show_html_output(text):
    display(HTML(f"<div style='color: hotpink;'><b>{text}</b></div>"))

# %%
dupe_percent_order_id = (dupe_item_order/ len(item_order) ) * 100

# %%
# Call the new HTML function :
show_html_output(f"Percentage of order_id that are duplicates: {dupe_percent_order_id:.2f}%")
# Out:
# <div style='color: hotpink;'><b>Percentage of order_id that are duplicates: 90.10%</b></div>

# %%
#display(HTML("<div style='color: hotpink;'><b>Percentage of order_id that are duplicates: </b></div>"))
#dupe_percent_order_id = (dupe_item_order/ len(item_order) ) * 100
#print(f"Percentage of duplicate order_id: {dupe_percent_order_id:.2f}%")

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 ⚠️</b>
#
#
# You can create a function for the HTML output that receives text as input.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 ✔️</h2>
#
# Nice!
#
# </div>

# %%
#print(f"Number of rows in product_id: {len(item_order['product_id'])}")
#print()

#dupe_prod_order = item_order.duplicated(subset='product_id').sum()
#Marks all occurances of duplicates as True
#dupe_item_order = item_order['order_id'].duplicated(keep=False)
#print(f"Number of duplicate product_id: {dupe_prod_order}")

#display(HTML("<div style='color: hotpink;'><b>Percentage of product_id that are duplicates: </b></div>"))

#Calculate percentage of missing product_id
#dupe_percent_prod_id = round(dupe_prod_order / len(item_order) * 100, 2)
#print(f"Percentage of duplicate product_id: {dupe_percent_prod_id:.2f}%")

# %%
# added BOTH to my subset : 'order_id', 'product_id'

# %%
# find duplicates based on BOTH 'order_id' and 'product_id' columns
dupe_prod_order = item_order.duplicated(subset=['order_id', 'product_id']).sum()

# Call the new HTML function :
show_html_output(f"Number of duplicate 'order_id' - 'product_id' pairs: {dupe_prod_order}")
# Out:
# <div style='color: hotpink;'><b>Number of duplicate 'order_id' - 'product_id' pairs: 0</b></div>

# %%
#Calculate percentage of missing product_id
dupe_percent_prod_id = round(dupe_prod_order / len(item_order) * 100, 2)

# Call the new HTML function :
show_html_output(f"Percentage of duplicate product_id: {dupe_percent_prod_id:.2f}%")
# Out:
# <div style='color: hotpink;'><b>Percentage of duplicate product_id: 0.00%</b></div>

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>Are there duplicates in 'order_id' and 'product_id' ?</b>
# <br>
# - There are 0 duplicates.
# </div></font color>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 ✔️</h2>
#
# Excellent job!
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Are there any `'order_id'` - `'product_id'` duplicates?
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  2 ❌</b>
#
# Imagine you are looking for the duplicates in the dataframe:
#
# ```python
#
# John Smith 35
#
# John Smith 8
#
# John Adams 21
# ```
#
#
# There are three columns: first name, last name, and age. If we apply `duplicated` to this dataframe, we will not find any duplicates, since at least one of the values differs. However, if we try to find `'first name' - 'last name'` duplicates, we will notice that there are two people with the same full name, John Smith.
#
#
# Apply the same logic and try to look for the `'order_id'` - `'product_id'` duplicates. </div>

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>item_order dataset cleanup: </b>
# <br>
# - I checked for duplicate rows in the item_order dataset. There were no duplicates. <br>
# - I checked for duplicates in the order_id column. 90% of the order_id column were duplicates.<br>
# - I checked for duplicates in the product_id column. 99% of the product_id column were duplicates.
# </div></font color>

# %% [markdown]
# <h2 style="color:red;">Find and remove missing values</h2>

# %% [markdown]
# ### `products` data frame

# %%
display(products)
# Out:
#        product_id                                       product_name  \
# 0               1                         chocolate sandwich cookies
# 1               2                                   all-seasons salt
# 2               3               robust golden unsweetened oolong tea
# 3               4  smart ones classic favorites mini rigatoni wit...
# 4               5                          green chile anytime sauce
# ...           ...                                                ...
# 49689       49690                      high performance energy drink
# 49690       49691                      original pancake & waffle mix
# 49691       49692    organic instant oatmeal light maple brown sugar
# 49692       49693                             spring water body wash
# 49693       49694                            burrito- steak & cheese
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 2            94              7
# ...

# %%
products['product_name'].value_counts(0)
# Out:
# green tea with ginseng and honey                    3
# bleu cheese salad dressing and dip                  2
# tomato and basil pasta sauce                        2
# top the tater chive & onion sour cream              2
# vitamin d3 2000 iu                                  2
#                                                    ..
# brown sugar and cinnamon steel cut quick oatmeal    1
# pure & natural sour cream                           1
# anchovies with capers in olive oil                  1
# high protein pretzels                               1
# plums                                               1
# Name: product_name, Length: 48332, dtype: int64

# %%
show_html_output("Are all of the missing product names associated with aisle ID 100?")
# Out:
# <div style='color: hotpink;'><b>Are all of the missing product names associated with aisle ID 100?</b></div>

# %%
show_html_output("How many missing product names are there?")
# Out:
# <div style='color: hotpink;'><b>How many missing product names are there?</b></div>

# %%
missing_prod_names = products['product_name'].isna()
total_missing_prod_names = missing_prod_names.sum()

print("Sum of missing product names:")
print(total_missing_prod_names)
print()

aisle100_and_NaN = products[(products['aisle_id'] == 100) & (products['product_name'].isna())]

print("Rows with missing product names associated with aisle ID 100:")
print(aisle100_and_NaN.shape[0])
print()

percent_assoc_w_aisle100 = (aisle100_and_NaN.shape[0] / total_missing_prod_names) * 100
print("Percentage of missing product names associated with aisle ID 100:")
print(str(percent_assoc_w_aisle100) + "%")
# Out:
# Sum of missing product names:
# 1258
#
# Rows with missing product names associated with aisle ID 100:
# 1258
#
# Percentage of missing product names associated with aisle ID 100:
# 100.0%

# %%
show_html_output("Are all of the missing product names associated with department ID 21?")
# Out:
# <div style='color: hotpink;'><b>Are all of the missing product names associated with department ID 21?</b></div>

# %%
dept21_and_NaN = products[(products['department_id'] == 21) & (products['product_name'].isna())]

if total_missing_prod_names == len(dept21_and_NaN):
    print("Yes, all of the missing product names are associated with department ID 21.")
else:
    print("No. Not all missing product names are associated with department ID 21.")
# Out:
# Yes, all of the missing product names are associated with department ID 21.

# %%
# What is this aisle and department?
# Check unique aisle_id and department_id for missing product names
unique_aisle_ids = products[missing_prod_names]['aisle_id'].unique()
print(f"Aisle_id associated with missing product names: {unique_aisle_ids}")

unique_dept_ids = products[missing_prod_names]['department_id'].unique()
print(f"Dept_id associated with missing product names: {unique_dept_ids}")
# Out:
# Aisle_id associated with missing product names: [100]
# Dept_id associated with missing product names: [21]

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>Merge products and depts dataframe, to gain access to department name.</b>
# </div></font color>

# %%
# Step 1: Merge the products and departments dataframes
merged_prod_depts_df = products.merge(depts, on='department_id', how='left')
display(merged_prod_depts_df.head(3))
# Out:
#    product_id                          product_name  aisle_id  department_id  \
# 0           1            chocolate sandwich cookies        61             19
# 1           2                      all-seasons salt       104             13
# 2           3  robust golden unsweetened oolong tea        94              7
#
#   department
# 0     snacks
# 1     pantry
# 2  beverages

# %%
#Print department name where department_id is 21
print(merged_prod_depts_df[merged_prod_depts_df['department_id'] == 21])
print(depts[depts['department_id'] == 21])
# Out:
#        product_id product_name  aisle_id  department_id department
# 37             38          NaN       100             21    missing
# 71             72          NaN       100             21    missing
# 109           110          NaN       100             21    missing
# 296           297          NaN       100             21    missing
# 416           417          NaN       100             21    missing
# ...           ...          ...       ...            ...        ...
# 49552       49553          NaN       100             21    missing
# 49574       49575          NaN       100             21    missing
# 49640       49641          NaN       100             21    missing
# 49663       49664          NaN       100             21    missing
# 49668       49669          NaN       100             21    missing
#
# [1258 rows x 5 columns]
#     department_id department
# 20             21    missing

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>Department name is missing.  I also went to the very top of the project, and read in the depts dataframe again, and when I run this: print(depts[depts['department_id'] == 21]) , it prints out the department name as "missing".</b>
# </div></font color>

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>Print aisle_id == 100 </b>
# </div></font color>

# %%
print(aisles[aisles['aisle_id'] == 100])
# Out:
#     aisle_id    aisle
# 99       100  missing

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>aisle_id 100 is missing the isle name. I also went up to the top of the project, reloaded in the aisles dataframe, ran this : display(aisles.head(100)) , and it also said "missing".</b>
# </div></font color>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# Try to print department from `departments` dataframe where department_id is 21 and aisle from `aisles` dataframes where aisle_id is 100. That's what they ask us about.
#
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Yes, each missing product name has a `'missing'` label.
# </div>

# %%
# Fill missing product names with 'Unknown'
products['product_name'] = products['product_name'].fillna('Unknown')
print(products['product_name'].tail(20))
# Out:
# 49674                cinnamon dolce keurig brewed k cups
# 49675                             ultra red energy drink
# 49676                    thick & chunky sloppy joe sauce
# 49677                    large chicken & cheese taquitos
# 49678                            famous chocolate wafers
# 49679                 all natural creamy caesar dressing
# 49680            spaghetti with meatballs and sauce meal
# 49681                                 california limeade
# 49682                                     cucumber kirby
# 49683          vodka- triple distilled- twist of vanilla
# 49684                 en croute roast hazelnut cranberry
# 49685                                   artisan baguette
# 49686         smartblend healthy metabolism dry cat food
# 49687                             fresh foaming cleanser
# 49688               fluffly vanilla marshmallow frosting
# 49689                      high performance energy drink
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
# Yes, we should replace them with some unique value, as it's hard to figure out a safer replacement.
# </div>

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>Products cleanup:</b>
# <br>
# - To find out if all rows with missing product names were associated with aisle 100, I first found all rows with missing values in product names, using isna(), then I got a count of how many rows with missing product names, using .sum(). Then I created a variable that had missing product name values, and ALSO had aisle_id equal to 100. Then I compared the number of rows with missing product names to the number of rows that had missing product names and aisle 100. The number was the same, so that means that 100% of the missing product names are associated with aisle 100.
# <br>
# <br>
# - To find out if all rows with missing product names were associated with department 21, I first found all rows with missing values in product names, and ALSO all rows that had missing product names and department equal to 21, and got a toal number of rows, using sum(). Since those two numbers were the same, that means that missing product names are associated with department 21,
# <br>
# <br>
# - To find out the name of the aisle and name of department that was associated with missing product names, I used unique.
# <br>
# <br>
# - I then replaced all missing values, in the product name, with the string "Unknown", using  .fillna()
# </div></font color>

# %% [markdown]
# ### `orders` data frame

# %%
display(orders)
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0        1515936   183418            11          6                 13
# 1        1690866   163593             5          5                 12
# 2        1454967    39980             4          5                 19
# 3        1768857    82516            56          0                 20
# 4        3007858   196724             2          4                 12
# ...          ...      ...           ...        ...                ...
# 478947   3210681     5617             5          1                 14
# 478948   3270802   112087             2          3                 13
# 478949    885349    82944            16          2                 11
# 478950    216274     4391             3          3                  8
# 478951   2071924     1730            18          1                 14
#
#         days_since_prior_order
# 0                         30.0
# 1                          9.0
# ...

# %%
show_html_output("Are there any missing values in the orders dataframe?")
# Out:
# <div style='color: hotpink;'><b>Are there any missing values in the orders dataframe?</b></div>

# %%
orders_missing_values = orders.isna().sum()
print("Missing values per column:")
print(orders_missing_values)
# Out:
# Missing values per column:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28817
# dtype: int64

# %%
print(len(orders))
print()
orders.info()
# Out:
# 478952
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478952 entries, 0 to 478951
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478952 non-null  int64
#  1   user_id                 478952 non-null  int64
#  2   order_number            478952 non-null  int64
#  3   order_dow               478952 non-null  int64
#  4   order_hour_of_day       478952 non-null  int64
#  5   days_since_prior_order  450135 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>Are there any missing values in the orders dataframe?</b>
# </div></font color>
#
# <div class="alert alert-info"><font color='hotpink'>
# <b>There is no missing data in the orders column.</b>
# </div></font color>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# Are there any missing values?
#
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Good!
#
# </div>

# %%
# Min value in the order_number column is 1
orders.describe()
# Out:
#            order_id        user_id   order_number      order_dow  \
# count  4.789520e+05  478952.000000  478952.000000  478952.000000
# mean   1.709953e+06  102966.654911      17.157563       2.775051
# std    9.869537e+05   59525.292863      17.704457       2.045901
# min    4.000000e+00       2.000000       1.000000       0.000000
# 25%    8.564698e+05   51413.750000       5.000000       1.000000
# 50%    1.709521e+06  102633.000000      11.000000       3.000000
# 75%    2.563002e+06  154419.000000      23.000000       5.000000
# max    3.421079e+06  206209.000000     100.000000       6.000000
#
#        order_hour_of_day  days_since_prior_order
# count      478952.000000           450135.000000
# mean           13.447034               11.101814
# std             4.224567                9.190004
# min             0.000000                0.000000
# 25%            10.000000                4.000000
# 50%            13.000000                7.000000
# ...

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>The min for each column in the orders dataframe.</b>
# </div></font color>

# %%
orders.min()
# Out:
# order_id                  4.0
# user_id                   2.0
# order_number              1.0
# order_dow                 0.0
# order_hour_of_day         0.0
# days_since_prior_order    0.0
# dtype: float64

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ⚠️</b>
#
#
# If you only need to find a minimum, then you can call the `min` method. </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Correct.
# </div>

# %%
# Are there any missing values where it's not a customer's first order?
# 'order_number': the number of times this customer has placed an order
filtered_orders = orders[orders['order_number'] > 1]

# Check for missing product names in these filtered orders
miss_val_not_cust_first_order = filtered_orders[filtered_orders['order_id'].isin(
    products[products['product_name'].isna()]
)]

has_missing_values = not miss_val_not_cust_first_order.empty

print(f"Are there missing product names in the rows where it is NOT a customer's first order? : {has_missing_values}")
# Out:
# Are there missing product names in the rows where it is NOT a customer's first order? : False

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>Are there missing values in the days_since_prior_order column?</b>
# </div></font color>

# %%
# Look for Nan
missing_values_count = orders['days_since_prior_order'].isna().sum()
print(f"Number of missing values in 'days_since_prior_order': {missing_values_count}")
# Out:
# Number of missing values in 'days_since_prior_order': 28817

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
#
# This is the task where we need the missing values in the `days_since_prior_order` column.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 ✔️</h2>
#
# So, we can conclude that all of the missing `'days_since_prior_order'` values match to a customer's first order.
# </div>

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>Are there missing values in the days_since_prior_order column?</b>
# - To find out if there are any missing values, in the rows, where it is NOT a customer's first order, I first created a new data frame, conditionally, with customer order greater than 1.
# - Next I used isin() to find out if the new dataframe was in the list of product names with missing values. There were 28817 missing values.
# </div></font color>

# %% [markdown]
# ### `order_products` data frame

# %%
item_order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  float64
#  3   reordered          int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %%
display(item_order)
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 0         2141543       11440               17.0          0
# 1          567889        1560                1.0          1
# 2         2261212       26683                1.0          1
# 3          491251        8670               35.0          1
# 4         2571142        1940                5.0          1
# ...           ...         ...                ...        ...
# 4545002    577211       15290               12.0          1
# 4545003   1219554       21914                9.0          0
# 4545004    692640       47766                4.0          1
# 4545005    319435         691                8.0          1
# 4545006   1398151       28733                9.0          0
#
# [4545007 rows x 4 columns]

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>Is there any missing data in the orders dataframe?</b>
# </div></font color>

# %%
orders_missing = item_order.isna().sum()
print(orders_missing)
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
show_html_output(f"There are {orders_missing[2]} values missing from the 'add_to_cart_order' column.")

#display(HTML(f"<div style='color: hotpink;'><b>There are {orders_missing[2]} values missing from the 'add_to_cart_order' column.</b></div>"))
# Out:
# <div style='color: hotpink;'><b>There are 836 values missing from the 'add_to_cart_order' column.</b></div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# Do we have any missing values?
#
# </div>

# %%
# What are the min and max values in this column?
item_order.describe()
# Out:
#            order_id    product_id  add_to_cart_order     reordered
# count  4.545007e+06  4.545007e+06       4.544171e+06  4.545007e+06
# mean   1.711166e+06  2.558084e+04       8.351669e+00  5.905025e-01
# std    9.850955e+05  1.409552e+04       7.080368e+00  4.917411e-01
# min    4.000000e+00  1.000000e+00       1.000000e+00  0.000000e+00
# 25%    8.608170e+05  1.353500e+04       3.000000e+00  0.000000e+00
# 50%    1.711530e+06  2.527200e+04       6.000000e+00  1.000000e+00
# 75%    2.561311e+06  3.793500e+04       1.100000e+01  1.000000e+00
# max    3.421079e+06  4.969400e+04       6.400000e+01  1.000000e+00

# %%
#Find min
#Describe excludes Nan
item_order_describe_min = item_order.describe()
item_order_min_values = item_order_describe_min.loc['min']
print(item_order_min_values)
# Out:
# order_id             4.0
# product_id           1.0
# add_to_cart_order    1.0
# reordered            0.0
# Name: min, dtype: float64

# %%
#Find max
item_order_describe_max = item_order.describe()
item_order_max_values = item_order_describe_max.loc['max']
print(item_order_max_values)
# Out:
# order_id             3421079.0
# product_id             49694.0
# add_to_cart_order         64.0
# reordered                  1.0
# Name: max, dtype: float64

# %%
# Find the minimum value in the 'add_to_cart_order' column
add_to_cart_order_min = item_order['add_to_cart_order'].min()
display(HTML(f"<div style='color: hotpink;'><b>The minimum value in the add_to_cart_order column is: {add_to_cart_order_min}</b></div>"))
# Out:
# <div style='color: hotpink;'><b>The minimum value in the add_to_cart_order column is: 1.0</b></div>

# %%
# Find the minimum value in the 'add_to_cart_order' column
add_to_cart_order_max = item_order['add_to_cart_order'].max()
display(HTML(f"<div style='color: hotpink;'><b>The maximum value in the add_to_cart_order column is: {add_to_cart_order_max}</b></div>"))
# Out:
# <div style='color: hotpink;'><b>The maximum value in the add_to_cart_order column is: 64.0</b></div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# I think they ask us about min and max values in the column that has missing values. What min and max values does it have?
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 ✔️</h2>
#
# Great.
#
# </div>

# %%
# Save all order IDs with at least one missing value in 'add_to_cart_order'
#Check for missing values in 'add_to_cart_order'
#missing_values_count = item_order['add_to_cart_order'].isna().sum()
#print(f"There are {missing_values_count} missing values in 'add_to_cart_order'.")

#save all order_id that have a missing value in the add_to_cart_order column.
#order_id_missing_values = item_order[item_order['add_to_cart_order'].isna()]['order_id'].unique()
#print(order_id_missing_values)

#Count the number of unique order_id with missing values
#count_missing_orders = len(order_id_missing_values)
#print(f"There are {count_missing_orders} unique order_ids with at least one missing value in 'add_to_cart_order'.")

# %%
show_html_output("Do all orders with missing values have more than 64 products?")
# Out:
# <div style='color: hotpink;'><b>Do all orders with missing values have more than 64 products?</b></div>

# %%
#Merge orders with products on 'product_id'
#merged_order_products = pd.merge(item_order, products, on='product_id', how='left')
#display(merged_order_products.head(3))
#merged_order_products.shape
#merged_order_products.columns
#There are 7 columns.

# %%
#Merge this new dataframe with the orders dataframe.
#combined_df = pd.merge(merged_order_products, orders, on='order_id', how='left')
#display(combined_df.head(3))
#combined_df.shape
#Now there are 12 columns.

# %%
#find orders with missing product names. Make new dataframe with 'order_id'
#orders_with_missing_values = combined_df[combined_df['product_name'].isna()]['order_id'].unique()
#orders_with_missing_values.shape
#print(orders_with_missing_values)

#find orders with any missing data
#make a new dataframe with 'order_id' that have any missing data 
#orders_with_any_missing_values = combined_df[combined_df.isnull().any(axis=1)]['order_id'].unique()
#print("Orders with missing data:", orders_with_any_missing_values)
#print(len(orders_with_any_missing_values))

# %%
#Count the number of products in each order
#order_counts = combined_df.groupby('order_id')['product_id'].count()
#print(order_counts)
#order_counts.shape

# %%
#Filter the counts for orders with missing values
#counts_for_orders_with_missing_values = order_counts.loc[orders_with_any_missing_values]
#counts_for_orders_with_missing_values.shape

# %%
#Check if all these orders that havve missing values have more than 64 products
#all() will return True only if all items meet that criteria of having more than 64 products
#all_have_more_than_64 = (counts_for_orders_with_missing_values > 64).all()
#display(all_have_more_than_64)

# %%
#if all_have_more_than_64:
    #display(HTML("<div style='color: hotpink;'><b>Yes. All orders with missing values have more than 64 products.</b></div>"))
#else:
    #display(HTML("<div style='color: hotpink;'><b>No. Not all orders with missing values have more than 64 products.</b></div>"))

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>
#
# - I merged item_order and products to gain access to product names.
# - I then merged this new dataframe with the orders dataframe to gain access to find out if there are orders that have missing values.
# - I used isnull to find out if any orders had any missing data.
# - I counted the number of products in each order.
# - I filtered that count to only include orders that have any missing values.
# - I used all() to find out whether or not ALL of the filtered orders that had missing data also had more than 64 products in the order.
# - I printed out the results. <b>Not all orders with missing values have more than 64 products.</b>
# </div></font color>

# %%
# RETRY June 28, 2024

# %%
# Find unique order_id values where add_to_cart_order is NaN.
# Use these order_id values to filter rows in the item_order DataFrame.
# Group by order_id and count the number of products for each order.
# Check if all these orders with missing values have more than 64 products.
# Display the result using HTML.

# %%
# Check for missing values in 'add_to_cart_order' column
missing_values_count = item_order['add_to_cart_order'].isna().sum()
display(missing_values_count)
# Out:
# 836

# %%
# Save unique order_id's with missing add_to_cart_order
order_id_missing_values = item_order[item_order['add_to_cart_order'].isna()]['order_id'].unique()

# %%
# Filter rows in item_order where order_id is in the order_id_missing_values list
filtered_orders = item_order[item_order['order_id'].isin(order_id_missing_values)]

# %%
# Count the number of products in each order
order_counts = filtered_orders.groupby('order_id').size()
print("Order counts:\n", order_counts)
# Out:
# Order counts:
#  order_id
# 9310        65
# 61355      127
# 102236      95
# 129627      69
# 165801      70
#           ...
# 2999801     70
# 3125735     86
# 3308010    115
# 3347453     71
# 3383594     69
# Length: 70, dtype: int64

# %%
# Check if all these orders have more than 64 products
all_have_more_than_64 = (order_counts > 64).all()

# %%
# Display the result using HTML
if all_have_more_than_64:
    show_html_output("Yes. All orders with missing values have more than 64 products.")
else:
    show_html_output("No. Not all orders with missing values have more than 64 products.")
# Out:
# <div style='color: hotpink;'><b>Yes. All orders with missing values have more than 64 products.</b></div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 ✔️</h2>
#
# Exactly, well done!
# </div>

# %% [markdown]
# - I checked for missing values in 'add_to_cart_order' column.
# - I saved unique order_id's with missing add_to_cart_order.
# - I filtered rows in item_order where order_id is in the order_id_missing_values list.
# - I counted the number of products in each order
# - I checked if all these orders have more than 64 products.
# - I displayed the result using my new HTML output function.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's commen ❌</b>
#
# So how can we answer the question? Do all orders with missing values have more than 64 products? Please keep in mind that a reader must understand everything without analyzing the code.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 ❌</b>
#
# Reconsider this solution please. First, take unique `order_id` values from the dataframe where `add_to_cart_order` are Nan-s. Then find rows in the `order_products` dataframe where `order_id` is in the list of unique values found before. Then group by `order_id` and count.
#
# </div>

# %%
#Before changing datatype of add_to_cart_order column
item_order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  float64
#  3   reordered          int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %%
# Replace missing values with 999 and convert column to integer type
item_order['add_to_cart_order'] = item_order['add_to_cart_order'].fillna(999).astype('int64')

#Test that Nan was changed to '999'
print(item_order[item_order['add_to_cart_order'] == 999])
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 737       2449164        5068                999          0
# 9926      1968313       43867                999          0
# 14394     2926893       11688                999          0
# 16418     1717990        4142                999          0
# 30114     1959075       42828                999          1
# ...           ...         ...                ...        ...
# 4505662   1800005        7411                999          0
# 4511400   1633337         260                999          0
# 4517562    404157        9517                999          0
# 4534112   1673227       17835                999          0
# 4535739   1832957       17949                999          1
#
# [836 rows x 4 columns]

# %%
#After changing datatype of add_to_cart_order column
item_order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 138.7 MB

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# - I used fillna to replace all Nan with '999' in the 'add_to_cart_order' column.
# <br>
# - I used astype to change datetype from float64 to int64.
# </div></font color>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
# Great! Now we are ready for the exploratory data analysis.
#
# </div>

# %% [markdown]
# # [A] Easy (must complete all to pass)

# %% [markdown]
# ### [A1] Verify that the `'order_hour_of_day'` and `'order_dow'` values in the `orders` tables are sensible (i.e. `'order_hour_of_day'` ranges from 0 to 23 and `'order_dow'` ranges from 0 to 6)

# %%
#Get value counts for the 'order_hour_of_day' column   
# Get value counts for the 'order_hour_of_day' column
order_hour_counts = orders['order_hour_of_day'].value_counts()
print("Value counts for the 'order_hour_of_day' column, before sorting.")
print(order_hour_counts)

# Sort the resulting Series by its index (which are the hours of the day)
sorted_order_hours = order_hour_counts.sort_index(ascending=True)

# Print the sorted result
print()
print("Value counts for the 'order_hour_of_day' column, after sorting.")
print(sorted_order_hours)
# Out:
# Value counts for the 'order_hour_of_day' column, before sorting.
# 10    40578
# 11    40032
# 15    39789
# 14    39631
# 13    39007
# 16    38112
# 12    38034
# 9     35896
# 17    31930
# 18    25510
# 8     25024
# 19    19547
# 20    14624
# 7     13043
# 21    11019
# 22     8512
# 23     5611
# 6      4215
# 0      3180
# 1      1763
# 5      1371
# 2       989
# 3       770
# 4       765
# Name: order_hour_of_day, dtype: int64
#
# Value counts for the 'order_hour_of_day' column, after sorting.
# 0      3180
# 1      1763
# 2       989
# 3       770
# 4       765
# 5      1371
# 6      4215
# 7     13043
# 8     25024
# 9     35896
# 10    40578
# 11    40032
# 12    38034
# 13    39007
# 14    39631
# 15    39789
# 16    38112
# 17    31930
# 18    25510
# 19    19547
# 20    14624
# 21    11019
# 22     8512
# 23     5611
# Name: order_hour_of_day, dtype: int64

# %%
#Get value counts for the 'order_dow' column   
# Get value counts for the 'order_dow' column
order_dow_counts = orders['order_dow'].value_counts()
print("Value counts for the 'order_dow' column, before sorting.")
print(order_dow_counts)

# Sort the resulting Series by its index (which are the hours of the day)
sorted_order_days = order_dow_counts.sort_index(ascending=True)

# Print the sorted result
print()
print("Value counts for the 'order_dow' column, after sorting.")
print(sorted_order_days)
# Out:
# Value counts for the 'order_dow' column, before sorting.
# 0    84090
# 1    82185
# 2    65833
# 5    63488
# 6    62649
# 3    60897
# 4    59810
# Name: order_dow, dtype: int64
#
# Value counts for the 'order_dow' column, after sorting.
# 0    84090
# 1    82185
# 2    65833
# 3    60897
# 4    59810
# 5    63488
# 6    62649
# Name: order_dow, dtype: int64

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>Are 'order_hour_of_day' (range from 0 to 23) and 'order_dow' (range 0 to 6) sensible ranges?</b>
# <br>
# - The order_hour_of_day, with range of 1-23, is good, because there are 24 hours in the day. This range should not change.
# <br>
# - The order_dow, with range 0-6, is good, because there are 7 days in the week. This range also should not change.
# <br>
# - I got the value counts, I sorted, lowest to highest, by index(because order_hour_of_day and order_dow were the index.), then I printed.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
# Correct.
#
# </div>

# %% [markdown]
# ### [A2] What time of day do people shop for groceries?

# %%
# Get mean (average) of the order_hour_of_day
orders['order_hour_of_day'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0         13
# 1         12
# 2         19
# 3         20
# 4         12
#           ..
# 478947    14
# 478948    13
# 478949    11
# 478950     8
# 478951    14
# Name: order_hour_of_day, Length: 478952, dtype: int64>

# %%
#describe will list the mean
orders.describe()
# Out:
#            order_id        user_id   order_number      order_dow  \
# count  4.789520e+05  478952.000000  478952.000000  478952.000000
# mean   1.709953e+06  102966.654911      17.157563       2.775051
# std    9.869537e+05   59525.292863      17.704457       2.045901
# min    4.000000e+00       2.000000       1.000000       0.000000
# 25%    8.564698e+05   51413.750000       5.000000       1.000000
# 50%    1.709521e+06  102633.000000      11.000000       3.000000
# 75%    2.563002e+06  154419.000000      23.000000       5.000000
# max    3.421079e+06  206209.000000     100.000000       6.000000
#
#        order_hour_of_day  days_since_prior_order
# count      478952.000000           450135.000000
# mean           13.447034               11.101814
# std             4.224567                9.190004
# min             0.000000                0.000000
# 25%            10.000000                4.000000
# 50%            13.000000                7.000000
# ...

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>The average time of day that people shop is about 1:20pm.</b>
# </div></font color>

# %%
avg_shop_hour = orders['order_hour_of_day'].mean()
hourly_orders = orders['order_hour_of_day'].value_counts().sort_index()
print(hourly_orders)
# Out:
# 0      3180
# 1      1763
# 2       989
# 3       770
# 4       765
# 5      1371
# 6      4215
# 7     13043
# 8     25024
# 9     35896
# 10    40578
# 11    40032
# 12    38034
# 13    39007
# 14    39631
# 15    39789
# 16    38112
# 17    31930
# 18    25510
# 19    19547
# 20    14624
# 21    11019
# 22     8512
# 23     5611
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>Created a graph that shows hours of day that customers shop</b>
# </div></font color>

# %%
#Create graph with shopping habits by hour of day
plt.figure(figsize=(10, 6))
#index refers to hours of day. values refers to the number of orders.
plt.bar(hourly_orders.index, hourly_orders.values, color="lightblue")
plt.axvline(avg_shop_hour, color='r', linestyle='--', label=f'Average Shopping Hour: {avg_shop_hour:.2f}')
plt.xlabel('Hour of Day', size=16)
plt.ylabel('Number of Orders', size=16)
plt.title('Number of Orders by Hour of Day', size=20)

plt.legend()
plt.show()

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>Average shopping hour is about 1:20pm</b>
# </div></font color>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Does the mean tell us much? Let's add a chart here :) Please do not forget to add a title and both axes labels on each chart :)
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Excellent chart!
# </div>

# %% [markdown]
# ### [A3] What day of the week do people shop for groceries?

# %%
orders_describe_mean = orders.describe()
orders_mean = orders_describe_mean.loc['mean', 'order_dow']
#print(orders_mean)

# Print the mean value for the 'order_dow' column
print("Mean value for order_dow:", round(orders_mean, 2))

# Print the mean value for the 'order_dow' column
#print("People show for groceries on:", int(order_dow_mean_rounded))
# Out:
# Mean value for order_dow: 2.78

# %%
import builtins
# Reset any shadowed built-ins
range = builtins.range

# Count the number of orders for each day of the week
orders_per_day = orders['order_dow'].value_counts().sort_index()

#labels for the x axis.
day_labels = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']

# Create the bar plot
plt.figure(figsize=(8, 5))
bars = plt.bar(orders_per_day.index, orders_per_day.values, color="pink", edgecolor="black")

# Highlight the average day (or the most frequent day in this context)
most_frequent_day = orders_per_day.idxmax()
#Make the bar red that is the day with the maximum amount of shopping
bars[most_frequent_day].set_color('red')

# Set custom x-tick labels to show as days of the week
plt.xticks(ticks=orders_per_day.index, labels=day_labels)
plt.xlabel('Day of Week', size=16)
plt.ylabel('Number of Orders', size = 16)
plt.title('Number of Orders by Day of Week', size = 20)
plt.legend([bars[most_frequent_day]], [f'Most Frequent Day: {day_labels[most_frequent_day]}'])
plt.show()

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>Most people shop for groceries on Sunday.</b>
# <br>
# - I used describe to get the mean for the order_dow column.
# </div></font color>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# - Same issue. Would you add a chart?
#
#
#
# - Does `mean` answer the question? What if `mode` is not 2 here? </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Perfect!
# </div>

# %% [markdown]
# ### [A4] How long do people wait until placing another order?

# %%
# Get the average wait time that people have before placing new order. describe() will give the mean
wait_describe = orders.describe()
wait_time_mean = wait_describe.loc['mean', 'days_since_prior_order']
#print(wait_time_mean)

# Print the mean value for the 'order_dow' column
print("Average wait time before placing a new order:", round(wait_time_mean, 0), " days.")
# Out:
# Average wait time before placing a new order: 11.0  days.

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <b>Created a graph to show how long people wait before reordering.</b>
# </div></font color>

# %%
# x should be order and reorder, y should be days
# need to get a list of customers and their reorders and the days

# %%
display(orders.head(3))
orders.info()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
#
#    days_since_prior_order
# 0                    30.0
# 1                     9.0
# 2                     2.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478952 entries, 0 to 478951
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478952 non-null  int64
#  1   user_id                 478952 non-null  int64
#  2   order_number            478952 non-null  int64
#  3   order_dow               478952 non-null  int64
#  4   order_hour_of_day       478952 non-null  int64
#  5   days_since_prior_order  450135 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %%
# Need to change datatype of days_since_prior_order from float to int.
# Need to get rid of Nan values first, otherwise, I get an error when changing datatype.
sum_reorder_days_nan = orders['days_since_prior_order'].isna().sum()
print(f"Number of Nan in days_since_prior_order column BEFORE: {sum_reorder_days_nan}")

orders['days_since_prior_order'] = orders['days_since_prior_order'].fillna(0)
sum_reorder_days_cleaned = orders['days_since_prior_order'].isna().sum()
print(f"Number of Nan in days_since_prior_order column AFTER changing all Nan to '0': {sum_reorder_days_cleaned}")

# 'days_since_prior_order' is float64. This needs to change to type int.
orders['days_since_prior_order'] = orders['days_since_prior_order'].astype(int)

# Verify column type
print(f"Data type of days_since_prior_order: {orders['days_since_prior_order'].dtype}")
# Out:
# Number of Nan in days_since_prior_order column BEFORE: 28817
# Number of Nan in days_since_prior_order column AFTER changing all Nan to '0': 0
# Data type of days_since_prior_order: int64

# %%
print(orders['days_since_prior_order'].head(5))
# Out:
# 0    30
# 1     9
# 2     2
# 3    10
# 4    17
# Name: days_since_prior_order, dtype: int64

# %%
# Count the number of orders for each 'days_since_prior_order'
days_since_prior_order_counts = orders['days_since_prior_order'].value_counts().sort_index()
print(days_since_prior_order_counts.head(5))
# Out:
# 0    38406
# 1    20179
# 2    27138
# 3    30224
# 4    31006
# Name: days_since_prior_order, dtype: int64

# %%
# Create the bar plot of days before reordering
plt.figure(figsize=(10, 6))
bars = plt.bar(days_since_prior_order_counts.index, days_since_prior_order_counts.values, color="yellow", edgecolor="black")

# Set title, x and y labels, and set custom x-tick labels
plt.xticks(days_since_prior_order_counts.index)
plt.xlabel('Days Since Prior Order', size=16)
plt.ylabel('Number of Orders', size=16)
plt.title('Days Waited Before Reordering', size=20)
#plt.legend([bars[days_since_prior_order_counts.index.get_loc(days_since_prior_order_counts)]], [f'Days before reorder: {days_since_prior_order_counts}'])

plt.show()

# %% [markdown]
# <div class="alert alert-info" style="color: hotpink;">
#   <b>The majority of people waited 30 days before reordering.</b>
#   <br>
#   - The average wait time is 11 days though.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="color: hotpink;">
#   <b>Getting the days since prior order.</b>
# <br>
# - I used describe to get the mean (avg) of number of days before a customer reordered.
# <br>
# - I used isna() and sum() to get the number of Nan in the days_since_prior_order, then filled the Nan values with '0'.
# <br>
# - I changed the datatype of days_since_prior_order, from float to int, because it did not make sense to think of days in partial numbers.
# <br>
# - I then sorted the value counts of days_since_prior_order so that they will list out, in ascending order on the graph.
# <br>
# - I think created a bar graph that has the days on the x axis, and the number of orders on the y axis.
# - I was surprised to see that the outcome of most people waiting 30 days before reordering, is much different than the results that I got of just getting the mean of 'days_since_prior_order'.
# </div></font color>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Please try to display a chart here as well.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
# Correct. You can also apply the `plot` method right after the `value)counts()`.
#
# </div>

# %% [markdown]
# # [B] Medium (must complete all to pass)

# %% [markdown]
# ### [B1] Is there a difference in `'order_hour_of_day'` distributions on Wednesdays and Saturdays? Plot the histograms for both days and describe the differences that you see.

# %%
# Filter orders for Wednesdays and also Saturdays
weds_orders = orders[orders['order_dow'] == 3]['order_hour_of_day']
sat_orders = orders[orders['order_dow'] == 6]['order_hour_of_day']

# %%
display(weds_orders.head(3))
# Out:
# 6      8
# 16    15
# 28    10
# Name: order_hour_of_day, dtype: int64

# %%
display(sat_orders.head(3))
# Out:
# 0     13
# 11    16
# 14    11
# Name: order_hour_of_day, dtype: int64

# %%
plt.figure(figsize=(14, 6))

# Histogram for Wednesday
plt.subplot(1, 2, 1)
weds_orders.plot(kind='hist', bins=20, title="Order-Hour-of_day Distribution for Wednesdays", ylabel="Frequency")
plt.xlabel('Hour of Day')

# Histogram for Saturday
plt.subplot(1, 2, 2)
sat_orders.plot(kind='hist', bins=20, title="Order-Hour-of_day Distribution for Saturdays", ylabel="Frequency", color = 'red')
plt.xlabel('Hour of Day')

# Display the plots
plt.show()

# %% [markdown]
# <div class="alert alert-info" style="color: hotpink;">
#   <b>Created a new graph that combines both graphs in to one.</b>
# <br>
# </div></font color>

# %%
#Need to check for Nan values in weds_orders and sat_orders

# %%
print(weds_orders.isna().sum())
# Out:
# 0

# %%
print(sat_orders.isna().sum())
# Out:
# 0

# %%
# Filter orders for Wednesdays and also Saturdays
weds_orders = orders[orders['order_dow'] == 3]['order_hour_of_day']
sat_orders = orders[orders['order_dow'] == 6]['order_hour_of_day']

# Create the histogram plot
plt.figure(figsize=(12, 8))
# Histogram for Wednesday
plt.hist(weds_orders, bins=24, color="blue", alpha=0.5, label='Wednesday')
# Histogram for Saturday
plt.hist(sat_orders, bins=24, color="red", alpha=0.5, label='Saturday')

# Set title, x and y labels
plt.xlabel('Hour of Day', size=16)
plt.ylabel('Number of Orders', size=16)
plt.title('Orders by Hour-of-Day, for Wednesday and Saturday', size=20)

#add more tick marks on x axis
plt.xticks(ticks=range(24), labels=range(1, 25))

# Add legend
plt.legend()
plt.show()

# %% [markdown]
# <div class="alert alert-info" style="color: hotpink;">
#   <b>Orders, by hour-of-day, comparing Wednesday vs Saturday.</b>
# <br>
# - I imported matplotlib, adding that to the first cell of the project, so that I would have access to create graphs.
# <br>
# I filtered order_hour_of_day values for all orders placed on Wednesday. And also filtered order_hour_of_day values for all orders placed on Saturday.
# <br>
# - I created two subplots, of graphs, to show orders by hour-of-day, for Wednesday, and another graph for Saturday.
# <br>
# - I also created a graph of orders by hour-of-day, plotting Wednesday and also Saturday on to the same graph. I used alpha to make sure that each graph was not opaque.
# <br>
# - I changed xticks on this graph, so that all 24 hours will be represented, so there are now 24 ticks.
# <br>
# - I changed the naming of these ticks, from 0-23 to 1-24.
# <br>
# - I gave the x label and the y label better names.
# <br>
# - I changed the number of bins to 24, to match the hours in the day.
# </div></font color>

# %% [markdown]
# <div class="alert alert-info" style="color: hotpink;">
# <b>The distribution of the orders, by hour-of-day, is almost exactly the same for Wednesday as it is for Saturday.</b>
# </div></font color>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
#
# Very good.
#
# </div>
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>  Reviewer's comment ⚠️</b>
#
#
# - Both charts can be displayed on one figure.
#
#
#
# - Labels such as `Count` or `Frequency` may seem unclear to a reader. Try to add lucid labels and titles.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Although the histogram is a useful chart to compare the distributions, we have to either use a bar chart for the categorical data or keep an eye on **bins** parameter. Since we have 24 hours, try to use 24 bins.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
#
# Correct!
# </div>

# %% [markdown]
# ### [B2] What's the distribution for the number of orders per customer?

# %%
# Filter orders for number of orders per customer. Count the number of orders for each group.
orders_per_customer = orders.groupby('user_id').size()
display(orders_per_customer.tail(8))
# Out:
# user_id
# 206200    3
# 206201    4
# 206202    3
# 206203    1
# 206206    7
# 206207    5
# 206208    9
# 206209    2
# dtype: int64

# %%
orders_per_customer.max()
# Out:
# 28

# %%
# Step 3: Plot the distribution
plt.figure(figsize=(10, 6))
plt.hist(orders_per_customer, bins=range(1, orders_per_customer.max() + 2), color = 'lightgreen', edgecolor='black', alpha=0.7)
plt.title('Distribution of Number of Orders per Customer')
plt.xlabel('Number of Orders per Customer')
plt.ylabel('Number of Customers')

# Display the plot
plt.show()

# %% [markdown]
# <div class="alert alert-info" style="color: hotpink;">
# <b>Most customers have ordered less than 5 times.</b>
# </div></font color>

# %% [markdown]
# <div class="alert alert-info" style="color: hotpink;">
# <b>Distribution of number of orders per customer.</b>
# <br>
# - I counted the number of rows in each group ( of user_id ) to find out how many times each customer ordered.
# <br>
# - I used max to find out what the max number of orders was that any customer had.
# <br>
# - I created a hist of orders per customer.
# <br>
# - I used max + 2 to add the right amount of bins, plus one extra bin padding on each side.
# <br>
# - I created an x label and y label that was descriptive.
# </div></font color>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
#
# Agreed.
#
# </div>

# %% [markdown]
# ### [B3] What are the top 20 popular products (display their id and name)?

# %%
# The order dataset holds this ...  order_id
# The item_order dataset holds these ... order_id,  product_id
# The products dataset holds these ... product_name,  product_id

# %%
#'1' means that it was the first item to be added to the cart.
#Grabs the top 20 products
#added_first = item_order[item_order['add_to_cart_order'] == 1]['product_id'].value_counts().head(20).reset_index()
#added_first.columns = ['product_id', 'first_added_count']
#print(added_first)

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
#
# > `item_order[item_order['add_to_cart_order'] == 1]`
#
#
#
# We are not asked about it in this task. All we need is to merge two dataframes and count rows, grouping data by id and name.
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="color: hotpink;">
# <b>Merge: </b>
# </div></font color>

# %%
#This merge adds product_name to the item_order dataframe, allowing me access to product_name
merged_item_products = item_order.merge(products, on='product_id')
display(merged_item_products.head(5))
# Out:
#    order_id  product_id  add_to_cart_order  reordered  \
# 0   2141543       11440                 17          0
# 1    147172       11440                  7          1
# 2   3341719       11440                  4          1
# 3   1938779       11440                  8          1
# 4   1728338       11440                 23          0
#
#                      product_name  aisle_id  department_id
# 0  chicken breast tenders breaded       129              1
# 1  chicken breast tenders breaded       129              1
# 2  chicken breast tenders breaded       129              1
# 3  chicken breast tenders breaded       129              1
# 4  chicken breast tenders breaded       129              1

# %%
grouped_prodID_prodName = merged_item_products.groupby(['product_id', 'product_name']).size().reset_index(name='count')

# %%
# sort by 'count' in ascending order to select only the top 20
top_20_products = grouped_prodID_prodName.sort_values(by='count', ascending=False).head(20)

# %%
# make index go from 1-20, as opposed to 0-19
top_20_products.index = range(1, len(top_20_products) + 1)

# %%
# Display the final DataFrame
display(top_20_products)
# Out:
#     product_id              product_name  count
# 1        24852                    banana  66050
# 2        13176    bag of organic bananas  53297
# 3        21137      organic strawberries  37039
# 4        21903      organic baby spinach  33971
# 5        47209      organic hass avocado  29773
# 6        47766           organic avocado  24689
# 7        47626               large lemon  21495
# 8        16797              strawberries  20018
# 9        26209                     limes  19690
# 10       27845        organic whole milk  19600
# 11       27966       organic raspberries  19197
# 12       22935      organic yellow onion  15898
# 13       24964            organic garlic  15292
# 14       45007          organic zucchini  14584
# 15       39275       organic blueberries  13879
# 16       49683            cucumber kirby  13675
# 17       28204        organic fuji apple  12544
# 18        5876             organic lemon  12232
# 19        8277  apple honeycrisp organic  11993
# ...

# %% [markdown]
# <div class="alert alert-info" style="color: hotpink;">
# <b>Bananas are the most popular Instacart product ordered.</b>
# <br>
# - I merged item_order and products dataframes to gain access to product names.
# <br>
# - I grouped by 'product_id', 'product_name' and counted the occurance of each, using size.
# <br>
# - I reset the index, so it would display as 1-20, as opposed to 0-19.
# <br>
# - I printed out the first 20 of the sorted dataframe, using .head.
# </div></font color>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
#
# Interesting :)
#
# </div>

# %% [markdown]
# # [C] Hard (must complete at least two to pass)

# %% [markdown]
# ### [C1] How many items do people typically buy in one order? What does the distribution look like?

# %% [markdown]
# ### [C2] What are the top 20 items that are reordered most frequently (display their names and product IDs)?

# %%
# Filter for reordered items. '1' means True
reordered_items = item_order[item_order['reordered'] == 1]
#print(reordered_items)


# Count the number of reorders for each unique product
reorder_counts = reordered_items['product_id'].value_counts().reset_index()
reorder_counts.columns = ['product_id', 'reorder_count']
print(reorder_counts)
# Out:
#        product_id  reorder_count
# 0           24852          55763
# 1           13176          44450
# 2           21137          28639
# 3           21903          26233
# 4           47209          23629
# ...           ...            ...
# 36223        2591              1
# 36224       29201              1
# 36225       27154              1
# 36226       10789              1
# 36227        2049              1
#
# [36228 rows x 2 columns]

# %%
#Merge new dataframe with select columns of products dataframe
sorted_reorder_counts = reorder_counts.sort_values('reorder_count', ascending=False)

# Select the top 20 unique reordered products' IDs
top_20_reorders = sorted_reorder_counts.head(20)

# Merge with the products dataframe to get the product names
top_20_reord_prod = top_20_reorders.merge(
    products[['product_id', 'product_name']].drop_duplicates(),
    on='product_id'
)

# Select only required columns
top_20_reord_prod = top_20_reord_prod[['product_id', 'product_name']]

# Reset the index and set it to start from 1 instead of 0
top_20_reord_prod.reset_index(drop=True, inplace=True)
top_20_reord_prod.index += 1

# Display the top 20 unique reordered products
display(top_20_reord_prod)
# Out:
#     product_id              product_name
# 1        24852                    banana
# 2        13176    bag of organic bananas
# 3        21137      organic strawberries
# 4        21903      organic baby spinach
# 5        47209      organic hass avocado
# 6        47766           organic avocado
# 7        27845        organic whole milk
# 8        47626               large lemon
# 9        27966       organic raspberries
# 10       16797              strawberries
# 11       26209                     limes
# 12       22935      organic yellow onion
# 13       24964            organic garlic
# 14       45007          organic zucchini
# 15       49683            cucumber kirby
# 16       28204        organic fuji apple
# 17        8277  apple honeycrisp organic
# 18       39275       organic blueberries
# 19        5876             organic lemon
# 20       49235       organic half & half

# %% [markdown]
# <div class="alert alert-info" style="color: hotpink;">
# <b>To find the top 20 items that are reordered most frequently: </b>
# <br>
# - I filtered to only find items that have been reordered.
# <br>
# - I counted the number of each unique product id.
# <br>
# - I changed the dataframe to only include these columns 'product_id', 'product_name'
# <br>
# - I reset the index, so it would display as 1-20, as opposed to 0-19.
# <br>
# - I printed out the first 20 of the sorted dataframe, using .head.
# </div></font color>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
#
# Correct!
# </div>

# %% [markdown]
# ### [C3] For each product, what proportion of its orders are reorders?

# %%
#item_order dataframe holds ... 'product_id' and 'reordered'
#products dataframe holds ...'product_id' and 'product name'
#display(products)
#display(item_order)

# %%
# Count total number of orders for each product.
# Product_id is the column on the left
total_orders_per_product = item_order['product_id'].value_counts()
print("Dataframe of value counts for product_id:")
print(total_orders_per_product.head(5))

# Count number of reorders for each product
# Filter for reordered items ('1' means that it was reordered)
reordered_items = item_order[item_order['reordered'] == 1]
reorders_per_product = reordered_items['product_id'].value_counts()
print()
print("Dataframe of all reordered items:")
print(reordered_items.head(5))
reordered_items.shape

# Count percentage of reorders
percent_reorders = reorders_per_product / total_orders_per_product
print()
print("Percentage of reorders before index reset:")
print(percent_reorders.head(3))
#Need to convert this to a dataframe.

# Convert to DataFrame
proportion_reorders_df = percent_reorders.reset_index()
proportion_reorders_df.columns = ['product_id', 'reorder_proportion']
print()
print("Index is reset:")
print(proportion_reorders_df)

# Merge with product names, to get product names
final_percent_reorders = proportion_reorders_df.merge(
    products[['product_id', 'product_name']],
    on='product_id',
    how='left'
)
#sort by reorder_proportion
#final_percent_reorders_sorted = final_percent_reorders.sort_values(by='reorder_proportion', ascending=False)

print()
print()
print("Final dataframe:")
display(final_percent_reorders.head(30))
# Out:
# Dataframe of value counts for product_id:
# 24852    66050
# 13176    53297
# 21137    37039
# 21903    33971
# 47209    29773
# Name: product_id, dtype: int64
#
# Dataframe of all reordered items:
#    order_id  product_id  add_to_cart_order  reordered
# 1    567889        1560                  1          1
# 2   2261212       26683                  1          1
# 3    491251        8670                 35          1
# 4   2571142        1940                  5          1
# 5   2456893       21616                  4          1
#
# Percentage of reorders before index reset:
# 1    0.564286
# 2         NaN
# 3    0.738095
# Name: product_id, dtype: float64
#
# Index is reset:
#        product_id  reorder_proportion
# 0               1            0.564286
# 1               2                 NaN
# 2               3            0.738095
# 3               4            0.510204
# 4               7            0.500000
# ...           ...                 ...
# ...

# %% [markdown]
# <div class="alert alert-info" style="color: hotpink;">
# <b>To find the top 20 items that are reordered most frequently: </b>
# <br>
# - I counted total number of orders for each product, using value_counts().
# <br>
# - I counted the number of reorders for each product, counting all '1's from the "reordered" column in the item_order dataframe.
# <br>
# - I counted the percentage of reorders. This created a series. I then had to change this series in to a dataframe because merge did not work on a series.
# <br>
# - I merged this new dataframe with products dataframe, to get access to the product names.
# <br>
# - I printed out the first 30. The reorder_proportion column shows the percentage of reorders for that product.
# </div></font color>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment ✔️</h2>
#
#
# Correct.
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment  ⚠️</h2>
#
#
#
# In order to find a rate, you can use the **mean** function: in the column `reordered`, 1 indicates the presence of reordering. Zero is its absence. So, the sum of the whole column will be equal to the sum of 1-s or the number of reorders, and applying the `count` method will return the total number of orders. Thus, to find the share of reorders, you need to divide this sum by the number of orders calculated with the `count` method, and this is nothing more than just a mean. Take a look:
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="color: hotpink;">
# <b>Tutor, thank you for your concise code: </b>
# </div></font color>

# %%
# Reviewer's code

#item_order.merge(products).groupby(['product_id', 'product_name'])['reordered'].mean()

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
#
# Glad to help! :)
# </div>

# %% [markdown]
# ### [C4] For each customer, what proportion of their products ordered are reorders?

# %% [markdown]
# ### [C5] What are the top 20 items that people put in their carts first?

# %%
# '1' means reordered
first_add_top_20 = item_order[item_order['add_to_cart_order'] == 1]
#display(first_add_top_20)

# Merge with the products DataFrame to get product names
merged_item_products = first_add_top_20.merge(products, on='product_id', how='inner')

# Count occurrences of each product name
product_counts = merged_item_products['product_name'].value_counts().reset_index()
product_counts.columns = ['product_name', 'count']

top_20_products = product_counts.sort_values(by='count', ascending=False).head(20)

# Reset the index to start from 1
top_20_products.index = range(1, len(top_20_products) + 1)

# Display the final DataFrame
display(top_20_products)
# Out:
#                    product_name  count
# 1                        banana  15562
# 2        bag of organic bananas  11026
# 3            organic whole milk   4363
# 4          organic strawberries   3946
# 5          organic hass avocado   3390
# 6          organic baby spinach   3336
# 7               organic avocado   3044
# 8                  spring water   2336
# 9                  strawberries   2308
# 10          organic raspberries   2024
# 11   sparkling water grapefruit   1914
# 12          organic half & half   1797
# 13                  large lemon   1737
# 14                         soda   1733
# 15     organic reduced fat milk   1397
# 16                        limes   1370
# 17                hass avocados   1340
# 18  organic reduced fat 2% milk   1310
# 19                  half & half   1309
# 20                  raspberries   1246

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
#
# We should consider items that were placed in the cart first (add_to_cart_order = 1).
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
#
# Good!
# </div>

# %% [markdown]
# <div class="alert alert-info" style="color: hotpink;">
# <b>To get the top 20 items that people put in their carts first:</b>
# <br>
# - I filtered to get only items that have been reordered.
# <br>
# - I merged this data with the products dataframe, so that I could gain access to product names.
# <br>
# - I changed this dataframe so that it only contained these columns 'product_name' 'count'
# <br>
# - I sorted this data, in ascending order, and used head to only grab the top 20 items.
# <br>
# - I reset the index so that it will display as 1-20, as opposed to 0-19.
# <br>
# - I printed this out.
# </div></font color>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Please don't forget to add the overall conclusion to your project: what has been done and what can be inferred from the results (average order size, something about time and so on).
#
# </div>

# %% [markdown]
# <div class="alert alert-info"><font color='hotpink'>
# <h1>  Instacart Ordering Habits of Customers conclusion: </h1>
# <h2>I explored 5 different Instacart datasets to gather information about buying habits of customers. I was able to gather a lot of information to conclude the following:<a class="tocSkip"></h2>
#
# - How many customers place orders for each hour of the day.
# - The majority of customers shop for groceries on Sunday, with Monday coming in a close 2nd.
# - The average time customers wait, before reordering, is 11 day. However, the majority of customers wait 30 days.<br>
# <br>
# <br>
# - The distribution for 'order_hour_of_day', for Wednesdays vs Saturdays is almost exactly the same.
# - The graphed the distribution of the number of orders that customers place.
# - The top 20 products that are ordered most frequently are bananas and strawberries
# <br>
# <br>
# - The top items that people purchase most frequently are bananas, strawberries, and spinach.
# <br>
# - I discovered the proportion of reorders for each product
# <br>
# - The top items that people put in their carts first are bananas, milk, strawberries, and avocado.
# </div></font color>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 ✔️</h2>
#
#
# Excellent job!
# </div>
